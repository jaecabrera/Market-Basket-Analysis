# %% [markdown]
# ### Market Basket Analysis
# ---

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import janitor
from plotnine import *
import mizani.formatters as miz
import pandas_flavor as pf
import spacy
import pickle

from spacy.attrs import IS_ALPHA
from spacy.matcher import Matcher
import nltk
from nltk.corpus import stopwords
from tqdm.notebook import tqdm

# nltk.download('stopwords')
COLOR = {"light_blue": "#d0e2ff", "dark_blue": "#0f62fe"}

# %%
# read dataset and select only the relevant columns for our analysis
retail_df = pd.read_csv('../Online_Retail.csv', encoding="ISO-8859-5")\
    .clean_names(case_type='snake')[['invoice_no', 'description', 'invoice_date']]\
    .to_datetime('invoice_date')

# %%
# view the first two dataframe
retail_df.head(10)
# Out:
#   invoice_no                          description        invoice_date
# 0     536365   WHITE HANGING HEART T-LIGHT HOLDER 2010-12-01 08:26:00
# 1     536365                  WHITE METAL LANTERN 2010-12-01 08:26:00
# 2     536365       CREAM CUPID HEARTS COAT HANGER 2010-12-01 08:26:00
# 3     536365  KNITTED UNION FLAG HOT WATER BOTTLE 2010-12-01 08:26:00
# 4     536365       RED WOOLLY HOTTIE WHITE HEART. 2010-12-01 08:26:00
# 5     536365         SET 7 BABUSHKA NESTING BOXES 2010-12-01 08:26:00
# 6     536365    GLASS STAR FROSTED T-LIGHT HOLDER 2010-12-01 08:26:00
# 7     536366               HAND WARMER UNION JACK 2010-12-01 08:28:00
# 8     536366            HAND WARMER RED POLKA DOT 2010-12-01 08:28:00
# 9     536367        ASSORTED COLOUR BIRD ORNAMENT 2010-12-01 08:34:00

# %%
# check total transactions of our dataset
retail_df.invoice_no.nunique()
# Out:
# 25900

# %%
# temporal start date
retail_df.invoice_date.min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
# temporal end date
retail_df.invoice_date.max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
# temporal duration
retail_df.invoice_date.max() - retail_df.invoice_date.min()
# Out:
# Timedelta('373 days 04:24:00')

# %%
# count unique items in transactions
retail_df.description.nunique()
# Out:
# 4223

# %% [markdown]
# #### Drop missing data

# %%
retail_df = retail_df.dropna()

# %% [markdown]
# #### Common Purchased Items

# %%
item_description = retail_df.description.str.upper().to_list()

# %%
def get_lemma(description: list) -> list:
    
    global COLOR
    
    # preprocess item description
    nlp = spacy.load('en_core_web_sm')
    matcher = Matcher(nlp.vocab)
    stop_words = set(stopwords.words('english'))
    
    # create pattern
    pattern = [{'IS_ALPHA': True}]
    matcher.add('ONLY_STR_ITEM', [pattern])

    lemma = []
    for doc in tqdm(
            nlp.pipe(item_description, disable=["tagger", "parser"]),
            desc='Preprocessing text',
            colour=COLOR['dark_blue'],
        ):
        
        # check for matches in matcher (only use non-digit docs)
            matches = matcher(doc)
            for match_id, start, end in matches:
                
                # get doc content
                span = doc[start:end]
        
                # check if text is not included in stop words
                if span not in stop_words:
                    lemma.append(span)
                
    return lemma

# %%
# get lemmatized of item description
# description_lemmatized = get_lemma(item_description)

# convert description to str to pickle
# item_description_lemmatized = [str(i) for i in description_lemmatized]

# %%
# with open('lemmatized_item_description.pickle', 'wb') as p:
#     pickle.dump(item_description_lemmatized, p)

# %%
with open('lemmatized_item_description.pickle', 'rb') as p:
    item_description_lemmatized = pickle.load(p)

# %%
# get the top 100 item word counts
item_word_counts = pd.Series(item_description_lemmatized).value_counts()[:100]

# change series to dataframe and rename cols
item_word_df: pd.DataFrame = item_word_counts\
    .to_frame()\
    .reset_index()\
    .rename_columns({'index': 'item_word'})

# %%
# get the item word values to use as 
item_word_list = item_word_df.item_word.to_list()

# %%
word_count_bar = ggplot(item_word_df, aes(x='item_word', y='count'))\
    + geom_col(fill=COLOR['light_blue'], color=COLOR['dark_blue'], width=.5)\
    + scale_x_discrete(name="Item word", limits=item_word_list)\
    + scale_y_continuous(labels=miz.comma_format(), expand=(0, 0, 0.1, 0))\
    + theme(
        figure_size=(12, 6),
        axis_title_x=element_text(size=8),
        axis_title_y=element_text(size=8),
        axis_text_x=element_text(angle=90, size=7),
        axis_text_y=element_text(size=7)
    )

# %%
word_count_bar.draw()

# %% [markdown]
# #### No. of transactions from Start to End

# %%
# create counts dataframe of total transactions per day
retail_df['invoice_date_1'] = retail_df.invoice_date.dt.strftime('%Y-%m-%d')
transactions_count_df = retail_df\
    .groupby(['invoice_date_1'])\
    .count()['invoice_no']\
    .reset_index(name='counts')\
    .to_datetime('invoice_date_1')

# %%
transaction_line = ggplot(transactions_count_df, aes(x='invoice_date_1', y='counts'))\
    + geom_line()\
    + geom_area(fill=COLOR['light_blue'], color=COLOR['dark_blue'])\
    + scale_x_date(name="Invoice Date", expand=(0, 0), date_labels="%b")\
    + scale_y_continuous(labels=miz.comma_format(), expand=(0, 0, 0.1, 0))\
    + theme(
        figure_size=(9, 4), 
        axis_title_x=element_text(size=7),
        axis_title_y=element_text(size=7),
        axis_text_x=element_text(size=7),
        axis_text_y=element_text(size=7),
    )

# %%
transaction_line.draw()

# %% [markdown]
# #### Preprocessing Item Description

# %%
# to do so we can check for lowercase entries in our item description and assign them as null values
def get_lower_case_entries(df: pd.DataFrame, col: str) -> pd.DataFrame:
    """
    Maps the column and assert if entry is in lowercase. If so then it will be assign
    as null.
    """
    try:
        return df[col].apply(lambda x: x if x.isupper() else np.nan)
    except AttributeError:
        print(f"column '{col}' contains non-str type data entry.")

# %%
# description contains comments and missing entries which we need to clean before proceeding
retail_df[retail_df.description.str.contains('missing')]
# Out:
#        invoice_no  description        invoice_date invoice_date_1
# 218477     556046      missing 2011-06-08 12:56:00     2011-06-08
# 323469     565310     ?missing 2011-09-02 12:26:00     2011-09-02
# 324024     565385     ?missing 2011-09-02 15:46:00     2011-09-02
# 418129     572701      missing 2011-10-25 14:31:00     2011-10-25
# 464813     576185     missing? 2011-11-14 11:25:00     2011-11-14
# 493686     578245   ?? missing 2011-11-23 12:37:00     2011-11-23
# 497819     578476  ????missing 2011-11-24 12:45:00     2011-11-24
# 497820     578477   ???missing 2011-11-24 12:45:00     2011-11-24
# 497821     578478   ???missing 2011-11-24 12:45:00     2011-11-24
# 536908     581226      missing 2011-12-08 09:56:00     2011-12-08

# %%
# counts of lowercased entries for description
get_lower_case_entries(retail_df, 'description').isna().value_counts()
# Out:
# description
# False    537363
# True       3092
# Name: count, dtype: int64

# %%
# replace original dataframe description feature to updated w/ nulls
retail_df['description'] = get_lower_case_entries(retail_df, 'description')

# drop entries with null features
retail_df = retail_df.dropna()

# %% [markdown]
# #### Remvoing whitespaces

# %%
retail_df['description'] = retail_df.description.str.strip()

# %% [markdown]
# #### Other issues with text preprocessing
#
# * Items are labelled with 'Pack of', 'Set', 'Set of'
# * Same items but labelled with a plural word e.g. <br>
#
# > ZINC T-LIGHT HOLDER STAR LARGE
#
# AND
#
# > ZINC T-LIGHT HOLDER STARS LARGE

# %%
# addressing plural to singular form
import re
from textblob import TextBlob
import pandas_flavor as pf
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Plural Problem using Singularization

# %%
def presingularize(item):
    item_description = TextBlob(item)
    singular = [i.singularize() for i in item_description.words]
    return str.upper(' '.join(singular))

# %% [markdown]
# #### Item description common pattern removal

# %%
def remove_pattern(pattern, replacement=""):
    """
    Decorator that removes a specified pattern from a string.

    Args:
        pattern (str): The regular expression pattern to remove.
        replacement (str, optional): The replacement string (defaults to an empty string).

    Returns:
        function: The decorated function.
    """

    def decorator(func):
        def wrapper(x):
            expression = re.compile(pattern)
            removed_text = expression.sub(replacement, func(x)) 
            return removed_text
        return wrapper
    return decorator


@remove_pattern(r'\b\d{1,2}\sPIECE\b\s')
def remove_piece(x):
    return x  

@remove_pattern(r'\b(?:PACK\s\d{1,2}|PACK\sOF\s\d{1,2})\s')
def remove_packs_of(x):
    return x 

@remove_pattern(r'\b(?:SET\s\d{1,2}|SET\sOF\s\d{1,2})\s')
def remove_sets_of(x):
    return x

@remove_pattern(r'^\d{1,2}\s')
def remove_start_digits(x):
    return x

# %%
new_description = retail_df.description\
    .apply(remove_piece)\
    .apply(remove_packs_of)\
    .apply(remove_sets_of)\
    .apply(remove_start_digits)

# %%
# can also utilize pandas series str replace
# new_description = retail_df.description\
#     .str.replace(r'\b\d{1,2}\sPIECE\b\s', '')\
#     .str.replace(r'\b(?:PACK\s\d{1,2}|PACK\sOF\s\d{1,2})\s', '')\
#     .str.replace(r'\b(?:SET\s\d{1,2}|SET\sOF\s\d{1,2})\s', '')\
#     .str.replace(r'^\d{1,2}\s', '')

# %%
singularize_mapping = {k: presingularize(v) for k, v in zip(new_description.unique(), new_description.unique())}

# %%
retail_df['description'] = new_description.map(singularize_mapping)

# %% [markdown]
# #### Preprocessing for Frequent Itemset generation
# ---

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, apriori, fpmax

# %%
retail_df_test = retail_df.copy()[['invoice_no', 'description']]

# %%
transaction_df = retail_df_test\
    .groupby(['invoice_no'])\
    .agg({'description': lambda x: x})\
    .reset_index(drop=True)\
    .rename_columns({'description': 'basket'})

# %%
transaction_df.iloc[5].values
# Out:
# array([array(['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED',
#               'ALARM CLOCK BAKELIKE GREEN', 'PANDA AND BUNNY STICKER SHEET',
#               'STAR GIFT TAPE', 'INFLATABLE POLITICAL GLOBE',
#               'VINTAGE HEAD AND TAIL CARD GAME', 'SET/2 RED RETROSPOT TEA TOWEL',
#               'ROUND SNACK BOX SET OF4 WOODLAND', 'SPACEBOY LUNCH BOX',
#               'LUNCH BOX I LOVE LONDON', 'CIRCU PARADE LUNCH BOX',
#               'CHARLOTTE BAG DOLLY GIRL DESIGN', 'RED TOADSTOOL LED NIGHT LIGHT',
#               'TEA TOWEL I LOVE LONDON', 'VINTAGE SEASIDE JIGSAW PUZZLE',
#               'MINI JIGSAW CIRCU PARADE', 'MINI JIGSAW SPACEBOY',
#               'MINI PAINT SET VINTAGE', 'POSTAGE'], dtype=object)                ],
#       dtype=object)

# %%
transaction_to_fit = []
for i in np.arange(transaction_df['basket'].shape[0]):
    try:
        transaction_to_fit.append(transaction_df.iloc[i][0].tolist())
    except (AttributeError, ValueError, TypeError):
        transaction_to_fit.append(list(transaction_df.iloc[i]))

# %%
te = TransactionEncoder()
te_arr = te.fit(transaction_to_fit).transform(transaction_to_fit)
transaction_encoded_df = pd.DataFrame(te_arr, columns=te.columns_)

# %%
transaction_encoded_df.head(10)
# Out:
#    15CM CHRISTMA GLAS BALL 20 LIGHT  18PC WOODEN CUTLERY SET DISPOSABLE  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
# 5                             False                               False
# 6                             False                               False
# 7                             False                               False
# 8                             False                               False
# 9                             False                               False
#
#    200 BENDY SKULL STRAW  200 RED WHITE BENDY STRAW  \
# 0                  False                      False
# 1                  False                      False
# 2                  False                      False
# 3                  False                      False
# 4                  False                      False
# 5                  False                      False
# 6                  False                      False
# 7                  False                      False
# 8                  False                      False
# 9                  False                      False
#
#    3D CHRISTMA STAMP STICKER  3D DOG PICTURE PLAYING CARD  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
# 5                      False                        False
# 6                      False                        False
# 7                      False                        False
# 8                      False                        False
# 9                      False                        False
#
#    3D HEART HONEYCOMB PAPER GARLAND  3D KIT CARD FOR KID  \
# 0                             False                False
# 1                             False                False
# 2                             False                False
# 3                             False                False
# 4                             False                False
# 5                             False                False
# 6                             False                False
# 7                             False                False
# 8                             False                False
# 9                             False                False
#
#    3D SHEET OF CAT STICKER  3D SHEET OF DOG STICKER  ...  \
# 0                    False                    False  ...
# 1                    False                    False  ...
# 2                    False                    False  ...
# 3                    False                    False  ...
# 4                    False                    False  ...
# 5                    False                    False  ...
# 6                    False                    False  ...
# 7                    False                    False  ...
# 8                    False                    False  ...
# 9                    False                    False  ...
#
#    ZINC PLANT POT HOLDER  ZINC STAR T-LIGHT HOLDER  ZINC SWEETHEART SOAP DISH  \
# 0                  False                     False                      False
# 1                  False                     False                      False
# 2                  False                     False                      False
# 3                  False                     False                      False
# 4                  False                     False                      False
# 5                  False                     False                      False
# 6                  False                     False                      False
# 7                  False                     False                      False
# 8                  False                     False                      False
# 9                  False                     False                      False
#
#    ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# 0                             False                           False
# 1                             False                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                           False
# 5                             False                           False
# 6                             False                           False
# 7                             False                           False
# 8                             False                           False
# 9                             False                           False
#
#    ZINC T-LIGHT HOLDER STAR SMALL  ZINC TOP 2 DOOR WOODEN SHELF  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
# 5                           False                         False
# 6                           False                         False
# 7                           False                         False
# 8                           False                         False
# 9                           False                         False
#
#    ZINC WILLIE WINKIE CANDLE STICK  ZINC WIRE KITCHEN ORGANISER  \
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
# 5                            False                        False
# 6                            False                        False
# 7                            False                        False
# 8                            False                        False
# 9                            False                        False
#
#    ZINC WIRE SWEETHEART LETTER TRAY
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# 5                             False
# 6                             False
# 7                             False
# 8                             False
# 9                             False
#
# [10 rows x 3967 columns]

# %% [markdown]
# #### Apriori Algorithm
# Generates frequent itemsets by recursively generating new candidate itemsets based on the frequent itemsets from the previous iteration.
# And pruning the itemsets using a support-based pruning strategy.

# %%
apriori(transaction_encoded_df, min_support=.5, use_colnames=True).sort_values('support')
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %% [markdown]
# #### Frequent pattern growth Algorithm
#
# Compress the data in a frequent pattern tree (FP-tree)

# %%
fpgrowth(transaction_encoded_df, min_support=.5, use_colnames=True).sort_values('support', ascending=False)
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
frequent_itemset = fpmax(transaction_encoded_df, min_support=.5, use_colnames=True).sort_values('support', ascending=False)
frequent_itemset
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %% [markdown]
# #### Association

# %%
from mlxtend.frequent_patterns import association_rules

# %%
try:
    rules = association_rules(frequent_itemset, metric='confidence')
except ValueError:
    print('Empty DataFrame')
# Out:
# Empty DataFrame

# %% [markdown]
# ### Conclusion

# %%
# for instance using apriori with minimum support of 2%
frequent_itemset = apriori(transaction_encoded_df, min_support=.02, use_colnames=True).sort_values('support')

# %%
frequent_itemset.sort_values('support', ascending=False)
# Out:
#       support                              itemsets
# 209  0.098326  (WHITE HANGING HEART T-LIGHT HOLDER)
# 162  0.092645            (REGENCY CAKESTAND 3 TIER)
# 81   0.091193             (JUMBO BAG RED RETROSPOT)
# 127  0.072869                       (PARTY BUNTING)
# 107  0.068640             (LUNCH BAG RED RETROSPOT)
# ..        ...                                   ...
# 39   0.020118              (ENAMEL BREAD BIN CREAM)
# 21   0.020118        (CHOCOLATE THI WAY METAL SIGN)
# 130  0.020118          (PICNIC BASKET WICKER SMALL)
# 128  0.020075                    (PARTY METAL SIGN)
# 151  0.020032                (RED DINER WALL CLOCK)
#
# [271 rows x 2 columns]

# %% [markdown]
# #### Metrics for Association
# * Support - The support/coverage of a rule is the fraction of transactions that contain the rule
# * Confidence - Predictive power or accuracy of the rule
#
#     * $\text{Confidence} = \frac{Support_{x->y}}{Support_{x}}$
#     * For all transactions of with these items in antecdents 30% of them also include the purchase of the consequent.
# * Lift - Increased likelihood of the rule occuring relative to its typical rate of occurence
#     * $Lift_{x->y} = \frac{Confidence_{X->Y}}{Support_{y}}$
#     * Customers who bought X and Y were (1 - Lift) % less likely to also buy Z.
#     * If lift value < 1, e.g. 1.5 then customers who bought X and Y are 1.5 more likely to also buy Z.
# * Leverage - is the difference between the observed frequency of a rule and the frequency that would be expected if the antecendent and consequent were independent.
#     * Values will range from (-1 to 1) a value of 0 indicates independence of the antecedent and consequent.
#     * $Leverage_{x->y} = Support_{x->y} - Support_{x} * Support_{y}$
#     * e.g. Leverage = .05, Customers who bought X and Y were slighly less likely to also buy Z.
# * Conviction - quantifies how dependent the consequent is on the antecedent (Related to lift)
#     * Range from 0 to infinity.
#     * The higher the range the more likely the consequent is dependent on the antecedent.
#     * $Conviction = \frac{1 - Support_{y}}{1 - Confidence_{x->y}}$
#     * Interpretation if conviction = 0.58, The rule would be correct 42% of the time (1 - 0.58) more often if the consequent were dependent on the antecedent.
# * Zhang's - quantifies the degree of association or disocciation between the antecedent and the consequent.(-1 to 1) (Perfect disocciation and perfect association). Identifiy items not should be placed next to each other.
#
# $$
# Zhang_{x_y} = \frac
# {Support_{x->y} - (Support_{x} * Support_{y})}
# {max[Support_{x->y} * (1 - Support_{x})], [Support_{x} * (Support_{y} - Support_{x->y})]}
# $$

# %%
# for 2% support we have around 271 entries
rules = association_rules(frequent_itemset, metric='confidence', min_threshold=.6)
rules
# Out:
#                                           antecedents  \
# 0                                    (DOTCOM POSTAGE)
# 1                          (STRAWBERRY CHARLOTTE BAG)
# 2                  (RED HANGING HEART T-LIGHT HOLDER)
# 3                            (WOODLAND CHARLOTTE BAG)
# 4                       (CHARLOTTE BAG PINK POLKADOT)
# 5                         (JUMBO BAG WOODLAND ANIMAL)
# 6                              (DOLLY GIRL LUNCH BOX)
# 7                              (JUMBO BAG STRAWBERRY)
# 8                  (GARDENER KNEELING PAD CUP OF TEA)
# 9   (ROSE REGENCY TEACUP AND SAUCER, PINK REGENCY ...
# 10  (ROSE REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 11  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 12                   (PINK REGENCY TEACUP AND SAUCER)
# 13                 (PAPER CHAIN KIT VINTAGE CHRISTMA)
# 14                    (JUMBO BAG BAROQUE BLACK WHITE)
# 15                   (PINK REGENCY TEACUP AND SAUCER)
# 16                   (PINK REGENCY TEACUP AND SAUCER)
# 17                  (GREEN REGENCY TEACUP AND SAUCER)
# 18                       (ALARM CLOCK BAKELIKE GREEN)
# 19                           (JUMBO STORAGE BAG SUKI)
# 20                   (ROSE REGENCY TEACUP AND SAUCER)
# 21                  (GREEN REGENCY TEACUP AND SAUCER)
# 22                          (JUMBO BAG PINK POLKADOT)
#
#                                           consequents  antecedent support  \
# 0                           (JUMBO BAG RED RETROSPOT)            0.030284
# 1                       (RED RETROSPOT CHARLOTTE BAG)            0.031351
# 2                (WHITE HANGING HEART T-LIGHT HOLDER)            0.032206
# 3                       (RED RETROSPOT CHARLOTTE BAG)            0.036007
# 4                       (RED RETROSPOT CHARLOTTE BAG)            0.032462
# 5                           (JUMBO BAG RED RETROSPOT)            0.037246
# 6                                (SPACEBOY LUNCH BOX)            0.036733
# 7                           (JUMBO BAG RED RETROSPOT)            0.035794
# 8                   (GARDENER KNEELING PAD KEEP CALM)            0.032676
# 9                   (GREEN REGENCY TEACUP AND SAUCER)            0.026226
# 10                   (PINK REGENCY TEACUP AND SAUCER)            0.033487
# 11                   (ROSE REGENCY TEACUP AND SAUCER)            0.027507
# 12  (ROSE REGENCY TEACUP AND SAUCER, GREEN REGENCY...            0.034213
# 13                    (PAPER CHAIN KIT 50 ' CHRISTMA)            0.035537
# 14                          (JUMBO BAG RED RETROSPOT)            0.040449
# 15                   (ROSE REGENCY TEACUP AND SAUCER)            0.034213
# 16                  (GREEN REGENCY TEACUP AND SAUCER)            0.034213
# 17                   (PINK REGENCY TEACUP AND SAUCER)            0.045148
# 18                         (ALARM CLOCK BAKELIKE RED)            0.042756
# 19                          (JUMBO BAG RED RETROSPOT)            0.051298
# 20                  (GREEN REGENCY TEACUP AND SAUCER)            0.047839
# 21                   (ROSE REGENCY TEACUP AND SAUCER)            0.045148
# 22                          (JUMBO BAG RED RETROSPOT)            0.052580
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 0             0.091193  0.020716    0.684062   7.501293  0.017954    2.876538
# 1             0.044849  0.020929    0.667575  14.885014  0.019523    2.873283
# 2             0.098326  0.021357    0.663130   6.744222  0.018190    2.676624
# 3             0.044849  0.021656    0.601423  13.410025  0.020041    2.396406
# 4             0.044849  0.022467    0.692105  15.431970  0.021011    3.102200
# 5             0.091193  0.022980    0.616972   6.765602  0.019583    2.372695
# 6             0.038784  0.022980    0.625581  16.130079  0.021555    2.567224
# 7             0.091193  0.023279    0.650358   7.131701  0.020015    2.599251
# 8             0.039467  0.023450    0.717647  18.183499  0.022160    3.401888
# 9             0.045148  0.023450    0.894137  19.804665  0.022265    9.019681
# 10            0.034213  0.023450    0.700255  20.467381  0.022304    3.222029
# 11            0.047839  0.023450    0.852484  17.819970  0.022134    6.454651
# 12            0.033487  0.023450    0.685393  20.467381  0.022304    3.072130
# 13            0.049974  0.023706    0.667067  13.348188  0.021930    2.853507
# 14            0.091193  0.025329    0.626188   6.866657  0.021640    2.431188
# 15            0.047839  0.026226    0.766542  16.023462  0.024589    4.078509
# 16            0.045148  0.027507    0.803995  17.808071  0.025963    4.871571
# 17            0.034213  0.027507    0.609272  17.808071  0.025963    2.471759
# 18            0.046173  0.027593    0.645355  13.976913  0.025619    2.689524
# 19            0.091193  0.031309    0.610325   6.692704  0.026631    2.332217
# 20            0.045148  0.033487    0.700000  15.504636  0.031327    3.182841
# 21            0.047839  0.033487    0.741722  15.504636  0.031327    3.686573
# 22            0.091193  0.035580    0.676686   7.420405  0.030785    2.810909
#
#     zhangs_metric
# 0        0.893756
# 1        0.963010
# 2        0.880068
# 3        0.959996
# 4        0.966576
# 5        0.885162
# 6        0.973774
# 7        0.891698
# 8        0.976927
# 9        0.975079
# 10       0.984096
# 11       0.970581
# 12       0.984836
# 13       0.959170
# 14       0.890384
# 15       0.970806
# 16       0.977282
# 17       0.988473
# 18       0.969923
# 19       0.896577
# 20       0.982505
# 21       0.979736
# 22       0.913255

# %% [markdown]
# #### Example Analysis
# ---

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
retrospot_bag = Image.open("images/red-retrospot-bag.png")
woodland_bag = Image.open("images/woodland-bag.jpg")

# %% [markdown]
# ### Product Antecedent
# ---

# %%
plt.imshow(woodland_bag)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Product Consequent
# ---

# %%
plt.imshow(retrospot_bag)
plt.axis('off')
plt.show()

# %%
rules.iloc[3].to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b22b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b22b1_level0_col0" class="col_heading level0 col0" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b22b1_level0_row0" class="row_heading level0 row0" >antecedents</th>
#       <td id="T_b22b1_row0_col0" class="data row0 col0" >frozenset({'WOODLAND CHARLOTTE BAG'})</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row1" class="row_heading level0 row1" >consequents</th>
#       <td id="T_b22b1_row1_col0" class="data row1 col0" >frozenset({'RED RETROSPOT CHARLOTTE BAG'})</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row2" class="row_heading level0 row2" >antecedent support</th>
#       <td id="T_b22b1_row2_col0" class="data row2 col0" >0.036007</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row3" class="row_heading level0 row3" >consequent support</th>
#       <td id="T_b22b1_row3_col0" class="data row3 col0" >0.044849</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row4" class="row_heading level0 row4" >support</th>
#       <td id="T_b22b1_row4_col0" class="data row4 col0" >0.021656</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row5" class="row_heading level0 row5" >confidence</th>
#       <td id="T_b22b1_row5_col0" class="data row5 col0" >0.601423</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row6" class="row_heading level0 row6" >lift</th>
#       <td id="T_b22b1_row6_col0" class="data row6 col0" >13.410025</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row7" class="row_heading level0 row7" >leverage</th>
#       <td id="T_b22b1_row7_col0" class="data row7 col0" >0.020041</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row8" class="row_heading level0 row8" >conviction</th>
#       <td id="T_b22b1_row8_col0" class="data row8 col0" >2.396406</td>
#     </tr>
#     <tr>
#       <th id="T_b22b1_level0_row9" class="row_heading level0 row9" >zhangs_metric</th>
#       <td id="T_b22b1_row9_col0" class="data row9 col0" >0.959996</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Support**
# * Woodland bag were purchased around 3% from all transactions.
# * Retrospot bag were purchased around 4% from all transactions
# * Both items were purchased have about 2% of all transactions
#
# **Confidence**
# * For all the transactions of Woodland bag 60% of them also include Retrospot bag.
#
# **Lift**
# * Customers who bought Woodland Bag are 13x more likely to also buy retrospot bag.
#
# **Zhang**
# * 95% perfect association and both items should be placed close together.
